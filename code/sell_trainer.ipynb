# %% [markdown]
# # Train Sell

# %%
from agents.sell_agent_trainer import SellAgentTrainer

sell_trainer = SellAgentTrainer(
    ticker="AAPL",
    window_size=30,
    horizon=20,
    transaction_cost=0.001,
    lambda_dd=0.05,
    lambda_vol=0.01,
    hold_penalty_long=0.0,
    device="cpu",
)

sell_history = sell_trainer.train(
    n_episodes=50,
    warmup_dynamic=True,
    verbose=True,
)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# [*********************100%***********************]  1 of 1 completed
# [SellTrainer] Raw dataset: (1224, 10)
# [SellTrainer] After dropna: (1224, 10)
# [SellTrainer] state_df shape: (1194, 270)
# [SellTrainer] state_dim=270, actions=2
# [SellTrainer] Dynamic warmup set to: 238
# [Sell Ep 1/50] Reward=0.0028 | MeanTrade=0.0028 | Eps=0.995 | Steps=5 | Buffer=5 | Avg10=0.0028
# [Sell Ep 5/50] Reward=-0.0314 | MeanTrade=-0.0314 | Eps=0.978 | Steps=6 | Buffer=23 | Avg10=-0.0225
# [Sell Ep 10/50] Reward=0.0309 | MeanTrade=0.0309 | Eps=0.954 | Steps=4 | Buffer=48 | Avg10=-0.0002
# [Sell Ep 15/50] Reward=-0.0273 | MeanTrade=-0.0273 | Eps=0.933 | Steps=5 | Buffer=71 | Avg10=0.0153
# [Sell Ep 20/50] Reward=-0.0078 | MeanTrade=-0.0078 | Eps=0.912 | Steps=5 | Buffer=93 | Avg10=0.0137
# [Sell Ep 25/50] Reward=-0.0398 | MeanTrade=-0.0398 | Eps=0.882 | Steps=11 | Buffer=124 | Avg10=0.0036
# [Sell Ep 30/50] Reward=0.0466 | MeanTrade=0.0466 | Eps=0.861 | Steps=4 | Buffer=146 | Avg10=-0.0018
# [Sell Ep 35/50] Reward=-0.0078 | MeanTrade=-0.0078 | Eps=0.838 | Steps=4 | Buffer=171 | Avg10=0.0095
# [Sell Ep 40/50] Reward=-0.0069 | MeanTrade=-0.0069 | Eps=0.816 | Steps=5 | Buffer=194 | Avg10=-0.0097
# [Sell Ep 45/50] Reward=-0.0247 | MeanTrade=-0.0247 | Eps=0.797 | Steps=4 | Buffer=214 | Avg10=-0.0145
# [Sell Ep 50/50] Reward=-0.0077 | MeanTrade=-0.0077 | Eps=0.771 | Steps=5 | Buffer=241 | Avg10=-0.0077
#
# SellAgent Training COMPLETE.
# Final 5 episode rewards: [-0.030834401214422578, -0.03179637468556209, -0.03220143290047844, 0.0188879645762429, -0.007651063707256271]
